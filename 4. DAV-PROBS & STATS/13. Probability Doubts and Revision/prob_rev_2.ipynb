# %%
import pandas as pd

# %%
walmart = pd.read_csv("walmart-data.csv.txt")

# %%
walmart.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
male_purchases = walmart[walmart["Gender"] == "M"]["Purchase"]
female_purchases = walmart[walmart["Gender"] == "F"]["Purchase"]

male_purchases = male_purchases.dropna()
female_purchases = female_purchases.dropna()

# %%
print(f"Number of male purchases: {len(male_purchases)}")
print(f"Number of female purchases: {len(female_purchases)}")
# Out:
# Number of male purchases: 414259
# Number of female purchases: 135809

# %%
male_purchases.mean() #-> sample mean
# Out:
# 9437.526040472265

# %%
female_purchases.mean() #-> sample mean
# Out:
# 8734.565765155476

# %%
n = len(female_purchases)

sample_male = np.random.permutation(male_purchases)[:n]
sample_female = np.random.permutation(female_purchases)[:n]

# %%
sample_mean_male = male_purchases.mean()
sample_mean_female = female_purchases.mean()

sample_std_male = male_purchases.std()
sample_std_female = female_purchases.std()

# %%
left_m = sample_male.mean() - (sample_std_male / np.sqrt(n) * 1.96)
right_m = sample_male.mean() + (sample_std_male / np.sqrt(n) * 1.96)

print(f"The population mean lies between [{left_m}, {right_m}] for males.")
# Out:
# The population mean lies between [9396.04301453785, 9450.208927527843] for males.

# %%
left_f = sample_female.mean() - (sample_std_female / np.sqrt(n) * 1.96)
right_f = sample_female.mean() + (sample_std_female / np.sqrt(n) * 1.96)

print(f"The population mean lies between [{left_f}, {right_f}] for females.")
# Out:
# The population mean lies between [8709.211081242413, 8759.920449068539] for females.

# %%
## Credit: Salil Trehan
N = 50000000
n = 135809

male_bootstrap_survey = []
female_bootstrap_survey = []
for i in range(sampling):
    female_boot_data = np.random.choice(female_data, size=n)
    male_boot_data = np.random.choice(male_data, size=n)
    female_bootstrap_survey.append(np.mean(female_boot_data)) 
    male_bootstrap_survey.append(np.mean(male_boot_data))

# %%
## Check for the combinatorics question
a = 365
b = 365 * 364 * 363 * 362 
c = (365 * 364 * 363) * 6 + (365 * 364) * 3
d = (365 * 364) * 4

(a + b + c + d) == 365**4
# Out:
# True
