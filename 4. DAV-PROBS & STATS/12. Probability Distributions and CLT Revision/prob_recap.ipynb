# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Three interviews

# %%
binom.pmf(k=0, n=3, p=0.1) # Prob of 0 offer letters
# Out:
# 0.7290000000000001

# %%
binom.pmf(k=1, n=3, p=0.1) # Prob of 1 offer letters
# Out:
# 0.24300000000000008

# %%
binom.pmf(k=2, n=3, p=0.1) # Prob of 2 offer letters
# Out:
# 0.02700000000000001

# %%
binom.pmf(k=3, n=3, p=0.1) # Prob of 3 offer letters
# Out:
# 0.0010000000000000002

# %%
x_values = [0, 1, 2, 3]
y_values = binom.pmf(x_values, n=3, p=0.1)

# %%
sns.barplot(x=x_values, y=y_values)
# Out:
# <AxesSubplot:>

# %%
# What is the probability of 2 or fewer successes
binom.pmf(k=0, n=3, p=0.1) + binom.pmf(k=1, n=3, p=0.1) + binom.pmf(k=2, n=3, p=0.1)
# Out:
# 0.9990000000000002

# %%
binom.cdf(k=2, n=3, p=0.1)
# Out:
# 0.999

# %%
# What is the prob of 2 or more success?
binom.pmf(k=2, n=3, p=0.1) + binom.pmf(k=3, n=3, p=0.1)
# Out:
# 0.02800000000000001

# %%
1 - binom.cdf(k=1, n=3, p=0.1)
# Out:
# 0.028000000000000025

# %% [markdown]
# # Height

# %%
df_hw = pd.read_csv("weight-height.csv")
df_hw
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df_height = df_hw["Height"]
df_height.head()
# Out:
# 0    73.847017
# 1    68.781904
# 2    74.110105
# 3    71.730978
# 4    69.881796
# Name: Height, dtype: float64

# %%
df_height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.histplot(df_height)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
people_shorter_than_akash = df_height[df_height<=72]

# %%
len(people_shorter_than_akash)
# Out:
# 9271

# %%
len(df_height)
# Out:
# 10000

# %%
frac_of_people_shorter_than_akash = len(people_shorter_than_akash) / len(df_height)
frac_of_people_shorter_than_akash
# Out:
# 0.9271

# %%
people_shorter_than_anurag = df_height[df_height<=68]

# %%
frac_of_people_shorter_than_anurag = len(people_shorter_than_anurag) / len(df_height)
frac_of_people_shorter_than_anurag
# Out:
# 0.6502

# %%
min_height = df_height.min()
min_height
# Out:
# 54.2631333250971

# %%
max_height = df_height.max()
max_height
# Out:
# 78.9987423463896

# %%
x_values = np.linspace(min_height, max_height, 100)
y_values = []
total = len(df_height)

for x in x_values:
    people_shorter_than_x = df_height[df_height<=x]
    num_people_shorter_than_x = len(people_shorter_than_x)
    frac_people_shorter_than_x = num_people_shorter_than_x/total
    y_values.append(frac_people_shorter_than_x)
    
plt.plot(x_values, y_values)
